# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
from tensorflow.keras.layers import Input, Dense, Activation,Dropout
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow.compat.v2.feature_column as fc
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.preprocessing import MultiLabelBinarizer
import tensorflow as tf
import io
from tensorflow import keras
import seaborn as sns
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
import pickle as pk
from sklearn.decomposition import PCA as pca

# %%
df_name = "95"
layer1nodes = 256
prefix = "losh"

data_path = "../../RoboDocData"

df_path = f"{data_path}/{df_name}"

model_name = f"df{df_name}_{prefix}_n{layer1nodes}"

model_path = f"{df_path}/{model_name}"

if path.exists(model_path) == False:
    os.makedirs(model_path)

# %%
with open('dataframe90.pkl', 'rb') as f:
    clean_data = pk.load(f)


clean_data.pop('died_in_hospital')
# Out:
# Index([439, 'length_of_stay_hospital'], dtype='object')

# %%
train_dataset = clean_data.sample(frac=0.8, random_state=0)
test_dataset = clean_data.drop(train_dataset.index)

train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('length_of_stay_hospital')
test_labels = test_features.pop('length_of_stay_hospital')

print(train_labels)
print(test_labels)
# Out:
# 15799    10.14
# 23911    16.39
# 21058     5.28
# 46671     4.64
# 19210    15.79
#          ...
# 46354     3.64
# 412       4.78
# 12293    18.78
# 17267     9.94
# 25624    11.35
# Name: length_of_stay_hospital, Length: 38988, dtype: float64
# 10        1.97
# 11        8.28
# 13        1.83
# 19        7.73
# 21        0.59
#          ...
# 48699     4.98
# 48711     7.10
# 48714     2.56
# 48727     5.00
# 48729    13.07
# Name: length_of_stay_hospital, Length: 9747, dtype: float64

# %%
normalizer = preprocessing.Normalization()
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [0.6519749  0.5629169  0.26624912 0.44589788 0.4681354  0.2810506
#  0.2832906  0.31413963 0.302066   0.6084728  0.18087263 0.16249077
#  0.12076901 0.26394868 0.40388787 0.3700026  0.3857318  0.49160576
#  0.4431675  0.46679547 0.45534405 0.3370482  0.43570772 0.4371076
#  0.45284495 0.42502478 0.4055549  0.4634338  0.4306391  0.46189976
#  0.3963602  0.4628282  0.4665344  0.4818248  0.49545428 0.3989323
#  0.44080698 0.48461705 0.492791   0.4999732  0.37619498 0.45968997
#  0.46488395 0.47917804 0.42804343 0.48893997 0.47242296 0.3946071
#  0.4201022  0.39797482 0.46129394 0.4706735  0.4579279  0.38219905
#  0.3606899  0.49525404 0.44118991 0.464162   0.49648035 0.39882565
#  0.36293453 0.41414154 0.42992088 0.41646272 0.41133484 0.46143937
#  0.46613535 0.46394718 0.3992448  0.46507537 0.37487206 0.48906463
#  0.45829237 0.46692473 0.48340857 0.48200074 0.36059946 0.42447138
#  0.4519544  0.42955297 0.48847064 0.405438   0.49313948 0.482744
#  0.49280214 0.43121865 0.4200756  0.45589566 0.42055178 0.38118237
#  0.49069735 0.39947626 0.44595855 0.4452169  0.43738058 0.371657
#  0.4905368  0.47418815 0.48209497 0.49466124 0.4775045  0.4522824
#  0.41404498 0.44814548 0.45981798 0.48999625 0.4387399  0.4254341
#  0.4682072  0.49044752 0.4634147  0.49779433 0.4771453  0.43979147
#  0.4317657  0.47535533 0.38794643 0.43895072 0.43304315 0.45278862
#  0.41421035 0.39586887 0.43701783 0.3557045  0.39981276 0.44892758
#  0.38355455 0.47351155 0.4273795  0.47194403 0.39347637 0.35109285
#  0.41677937 0.46004108 0.45767903 0.46270207 0.3572731  0.4989874
#  0.4477589  0.45635593 0.42967167 0.47097048 0.43054953 0.36463946
#  0.47605786 0.46048757 0.48357642 0.4510125  0.40234372 0.4025482
#  0.42621243 0.4944693  0.46089184 0.4401622  0.40871835 0.3607481
#  0.42538545 0.475919   0.4616063  0.40853825 0.41598675 0.47341102
#  0.48053485 0.41299415 0.4017844  0.4854394  0.44375172 0.4693267
#  0.45815438 0.4252821  0.46764126 0.47932565 0.4744     0.4994487
#  0.4645714  0.44801718 0.40722257 0.44275022 0.4392657  0.47313553
#  0.49796113 0.40467194 0.4513194 ]
# "first = np.array(train_features[:5])\n\nwith np.printoptions(precision=2, suppress=True):\n  print('First example:', first)\n  print()\n  print('Normalized:', normalizer(first).numpy())\n"

# %%
METRICS=[tf.keras.metrics.MeanSquaredError(name="mean_squared_error", dtype=None)]

# %%
def build_and_compile_model(norm):
    model = keras.Sequential([
      norm,
      layers.Dense(16, activation='relu'),
      layers.Dense(16, activation='relu'),
      layers.Dense(1)
    ])

    
    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001),metrics=METRICS)
    return model

# %%
dnn_model = build_and_compile_model(normalizer)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='mean_squared_error', 
    verbose=1,
    patience=24,
    mode='max',
    restore_best_weights=True)

# %%
history = dnn_model.fit(
        train_features, train_labels,
        validation_split=0.2, epochs=128,
        callbacks=[early_stopping],)
# Out:
# Epoch 1/128
# 975/975 [==============================] - 1s 847us/step - loss: 5.4481 - mean_squared_error: 101.7722 - val_loss: 4.7917 - val_mean_squared_error: 73.8013
# Epoch 2/128
# 975/975 [==============================] - 1s 745us/step - loss: 4.6488 - mean_squared_error: 78.7679 - val_loss: 4.7509 - val_mean_squared_error: 72.2466
# Epoch 3/128
# 975/975 [==============================] - 1s 732us/step - loss: 4.5249 - mean_squared_error: 75.7009 - val_loss: 4.7106 - val_mean_squared_error: 72.0823
# Epoch 4/128
# 975/975 [==============================] - 1s 753us/step - loss: 4.4515 - mean_squared_error: 74.2359 - val_loss: 4.7115 - val_mean_squared_error: 73.8966
# Epoch 5/128
# 975/975 [==============================] - 1s 783us/step - loss: 4.3948 - mean_squared_error: 73.2709 - val_loss: 4.7295 - val_mean_squared_error: 71.3857
# Epoch 6/128
# 975/975 [==============================] - 1s 778us/step - loss: 4.3378 - mean_squared_error: 72.0022 - val_loss: 4.7688 - val_mean_squared_error: 70.0552
# Epoch 7/128
# 975/975 [==============================] - 1s 746us/step - loss: 4.2924 - mean_squared_error: 71.0186 - val_loss: 4.7509 - val_mean_squared_error: 70.6285
# Epoch 8/128
# 975/975 [==============================] - 1s 742us/step - loss: 4.2530 - mean_squared_error: 70.0513 - val_loss: 4.7146 - val_mean_squared_error: 70.8196
# Epoch 9/128
# 975/975 [==============================] - 1s 758us/step - loss: 4.2059 - mean_squared_error: 69.0829 - val_loss: 4.7362 - val_mean_squared_error: 70.4216
# Epoch 10/128
# 975/975 [==============================] - 1s 749us/step - loss: 4.1672 - mean_squared_error: 68.2502 - val_loss: 4.7453 - val_mean_squared_error: 71.1316
# Epoch 11/128
# 975/975 [==============================] - 1s 757us/step - loss: 4.1319 - mean_squared_error: 67.5173 - val_loss: 4.7472 - val_mean_squared_error: 71.7146
# Epoch 12/128
# 975/975 [==============================] - 1s 733us/step - loss: 4.0999 - mean_squared_error: 67.0489 - val_loss: 4.7545 - val_mean_squared_error: 72.1654
# Epoch 13/128
# 975/975 [==============================] - 1s 750us/step - loss: 4.0631 - mean_squared_error: 66.1771 - val_loss: 4.7987 - val_mean_squared_error: 71.5182
# Epoch 14/128
# 975/975 [==============================] - 1s 738us/step - loss: 4.0349 - mean_squared_error: 65.4851 - val_loss: 4.8870 - val_mean_squared_error: 70.8921
# Epoch 15/128
# 975/975 [==============================] - 1s 762us/step - loss: 4.0022 - mean_squared_error: 64.4665 - val_loss: 4.8097 - val_mean_squared_error: 71.8320
# Epoch 16/128
# 975/975 [==============================] - 1s 759us/step - loss: 3.9790 - mean_squared_error: 64.2357 - val_loss: 4.8174 - val_mean_squared_error: 73.2275
# Epoch 17/128
# 975/975 [==============================] - 1s 761us/step - loss: 3.9495 - mean_squared_error: 63.6276 - val_loss: 4.8727 - val_mean_squared_error: 71.9186
# Epoch 18/128
# 975/975 [==============================] - 1s 766us/step - loss: 3.9251 - mean_squared_error: 63.1095 - val_loss: 4.8674 - val_mean_squared_error: 72.4026
# Epoch 19/128
# 975/975 [==============================] - 1s 760us/step - loss: 3.9000 - mean_squared_error: 62.3117 - val_loss: 4.8619 - val_mean_squared_error: 73.4530
# Epoch 20/128
# 975/975 [==============================] - 1s 775us/step - loss: 3.8775 - mean_squared_error: 61.7232 - val_loss: 4.8942 - val_mean_squared_error: 72.7195
# Epoch 21/128
# 975/975 [==============================] - 1s 756us/step - loss: 3.8607 - mean_squared_error: 61.0033 - val_loss: 4.8952 - val_mean_squared_error: 72.8635
# Epoch 22/128
# 975/975 [==============================] - 1s 755us/step - loss: 3.8348 - mean_squared_error: 61.0755 - val_loss: 4.9162 - val_mean_squared_error: 72.9925
# Epoch 23/128
# 975/975 [==============================] - 1s 758us/step - loss: 3.8143 - mean_squared_error: 60.5347 - val_loss: 4.9097 - val_mean_squared_error: 73.4633
# Epoch 24/128
# 975/975 [==============================] - 1s 761us/step - loss: 3.7945 - mean_squared_error: 59.7762 - val_loss: 4.9628 - val_mean_squared_error: 73.8249
# Epoch 25/128
# 975/975 [==============================] - 1s 756us/step - loss: 3.7811 - mean_squared_error: 59.1300 - val_loss: 4.9402 - val_mean_squared_error: 73.6559
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping

# %%
dnn_model.save('./model_reg')
# Out:
# INFO:tensorflow:Assets written to: ./model/assets

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = dnn_model.evaluate(test_features, test_labels, batch_size=128)
print(results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print("Generate predictions for 3 samples")
predictions = dnn_model.predict(test_features)
print("predictions shape:", predictions)
# Out:
# Evaluate on test data
# 77/77 [==============================] - 0s 722us/step - loss: 4.7943 - mean_squared_error: 71.4888
# [4.794316291809082, 71.48877716064453]
# Generate predictions for 3 samples
# predictions shape: [[ 7.7324514]
#  [ 5.9703655]
#  [ 3.4641652]
#  ...
#  [ 3.9425225]
#  [ 5.457998 ]
#  [11.7839155]]

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 10])
    plt.xlabel('Epoch')
    plt.ylabel('Error [length_of_stay]')
    plt.legend()
    plt.grid(True)

plot_loss(history)

# %%
print(test_labels.shape)

h = sns.jointplot(predictions.T[0], test_labels, test_labels, kind='hex', gridsize=150, xlim=(0,30), ylim=(0,30))
h.set_axis_labels('real length of stay', 'predicted length of stay', fontsize=16)
plt.suptitle("Regression 90")
# Out:
# (9747,)
# /home/shahin/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0.98, 'Regression 90')
